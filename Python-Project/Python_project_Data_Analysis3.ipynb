# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = pd.read_csv("C:/Users/ssing397/Downloads/archive/Loksabha_election_2024_results.csv")
a
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1        2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2        3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3        4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4        5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# ...    ...                        ...                        ...
# 8897  8898                West Bengal                   Uluberia
# 8898  8899                West Bengal                   Uluberia
# 8899  8900                West Bengal                   Uluberia
# 8900  8901                West Bengal                   Uluberia
# 8901  8902                West Bengal                   Uluberia
#
#                Candidate                                        Party  \
# 0        BISHNU PADA RAY                       Bharatiya Janata Party
# ...

# %%
a.isnull().sum()
# Out:
# ID              0
# State           0
# Constituency    0
# Candidate       0
# Party           0
# EVM Votes       0
# Postal Votes    0
# Total Votes     0
# % of Votes      0
# Result          0
# dtype: int64

# %%
a.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8897    False
# 8898    False
# 8899    False
# 8900    False
# 8901    False
# Length: 8902, dtype: bool

# %%
a.duplicated().sum()
# Out:
# 0

# %%
a.head(10)
# Out:
#    ID                      State               Constituency  \
# 0   1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1   2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2   3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3   4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4   5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 5   6  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 6   7  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 7   8  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8   9  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 9  10  Andaman & Nicobar Islands  Andaman & Nicobar Islands
#
#               Candidate                                     Party  EVM Votes  \
# 0       BISHNU PADA RAY                    Bharatiya Janata Party     102182
# 1    KULDEEP RAI SHARMA                  Indian National Congress      77829
# ...

# %%
a.dtypes
# Out:
# ID                int64
# State            object
# Constituency     object
# Candidate        object
# Party            object
# EVM Votes         int64
# Postal Votes      int64
# Total Votes       int64
# % of Votes      float64
# Result           object
# dtype: object

# %%
a.describe()
# Out:
#                 ID     EVM Votes  Postal Votes   Total Votes   % of Votes
# count  8902.000000  8.902000e+03   8902.000000  8.902000e+03  8902.000000
# mean   4451.500000  7.207582e+04    420.636711  7.249646e+04     6.088488
# std    2569.930382  1.788713e+05   1339.607914  1.798988e+05    14.630082
# min       1.000000  0.000000e+00      0.000000  0.000000e+00     0.000000
# 25%    2226.250000  1.085000e+03      3.000000  1.094250e+03     0.090000
# 50%    4451.500000  2.768500e+03      9.000000  2.781000e+03     0.240000
# 75%    6676.750000  9.677000e+03     49.000000  9.759500e+03     0.810000
# max    8902.000000  1.468549e+06  19827.000000  1.471885e+06    78.540000

# %%
a.shape
# Out:
# (8902, 10)

# %%
# Exploraatory data-analysis

# %%
party = a.groupby(['Party'], as_index=False)['Total Votes'].sum().sort_values(by='Total Votes', ascending=False).head(10)
party
# Out:
#                                      Party  Total Votes
# 158                 Bharatiya Janata Party    235973935
# 289               Indian National Congress    136759064
# 617                        Samajwadi Party     29549381
# 69            All India Trinamool Congress     28213393
# 282                            Independent     17844442
# 744  Yuvajana Sramika Rythu Congress Party     13316039
# 121                    Bahujan Samaj Party     13153818
# 698                           Telugu Desam     12775270
# 250              Dravida Munnetra Kazhagam     11754710
# 227    Communist Party of India  (Marxist)     11342553

# %%
plt.bar(party["Party"], party["Total Votes"])
plt.xticks(rotation="vertical")
plt.xlabel("Party")
plt.ylabel("Total Votes")
plt.title("Top 10 parties with heighest votes")
# Out:
# Text(0.5, 1.0, 'Top 10 parties with heighest votes')

# %%
sns.barplot(x="Party", y="Total Votes",data=party)
plt.xticks(rotation="vertical")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
party_evmvotes = a.groupby(['Party'], as_index=False)['EVM Votes'].sum().sort_values(by='EVM Votes', ascending=False).head(15)
party_evmvotes
# Out:
#                                         Party  EVM Votes
# 158                    Bharatiya Janata Party  234613216
# 289                  Indian National Congress  135910535
# 617                           Samajwadi Party   29466107
# 69               All India Trinamool Congress   28101370
# 282                               Independent   17755186
# 744     Yuvajana Sramika Rythu Congress Party   13174874
# 121                       Bahujan Samaj Party   13105155
# 698                              Telugu Desam   12569179
# 250                 Dravida Munnetra Kazhagam   11689879
# 227       Communist Party of India  (Marxist)   11237709
# 539                      Rashtriya Janata Dal   10062033
# 657     Shiv Sena (Uddhav Balasaheb Thackrey)    9522797
# 217                           Biju Janata Dal    9382711
# 55   All India Anna Dravida Munnetra Kazhagam    8906771
# 333                      Janata Dal  (United)    8020732

# %%
plt.figure(figsize=(25,7))
result = sns.barplot(x="Party", y="EVM Votes", data=party_evmvotes, color='Green')
result.bar_label(result.containers[0])

plt.title("Top 15 parties with there EVM votes")
plt.xticks(rotation='vertical')
plt.show()

# %%
party_result = a.groupby(['State'], as_index=False)['Total Votes'].sum().sort_values(by='Total Votes', ascending=False).head(10)
party_result
# Out:
#              State  Total Votes
# 33   Uttar Pradesh     87911642
# 35     West Bengal     60483687
# 19     Maharashtra     57179133
# 30      Tamil Nadu     43674048
# 4            Bihar     43448949
# 14       Karnataka     38793617
# 18  Madhya Pradesh     37940251
# 1   Andhra Pradesh     33729342
# 28       Rajasthan     33164877
# 9          Gujarat     29115599

# %%
plt.figure(figsize=(7,7))
plt.pie(party_result["Total Votes"],labels=party_result['State'],autopct="%0.1f%%")
plt.title("Top 10 states with highest Total votes")
plt.show()

# %%
Up = a[(a['State'] == 'Uttar Pradesh') & (a['Result'] == 'Won')]
Up
# Out:
#         ID          State    Constituency                         Candidate  \
# 7362  7363  Uttar Pradesh            Agra             PROF S P SINGH BAGHEL
# 7374  7375  Uttar Pradesh        Akbarpur  DEVENDRA SINGH ALIAS BHOLE SINGH
# 7384  7385  Uttar Pradesh         Aligarh               SATISH KUMAR GAUTAM
# 7399  7400  Uttar Pradesh       Allahabad                UJJWAL RAMAN SINGH
# 7414  7415  Uttar Pradesh  Ambedkar Nagar                       LALJI VERMA
# ...    ...            ...             ...                               ...
# 8244  8245  Uttar Pradesh       Shrawasti               RAM SHIROMANI VERMA
# 8257  8258  Uttar Pradesh         Sitapur                     RAKESH RATHOR
# 8266  8267  Uttar Pradesh       Sultanpur                   RAMBHUAL NISHAD
# 8276  8277  Uttar Pradesh           Unnao   SWAMI SACHCHIDANAND HARI SAKSHI
# 8285  8286  Uttar Pradesh        Varanasi                     NARENDRA MODI
#
# ...

# %%
rs = Up.groupby(['Constituency'], as_index=False)['Candidate'].describe()
rs
# Out:
#       Constituency count unique                               top freq
# 0             Agra     1      1             PROF S P SINGH BAGHEL    1
# 1         Akbarpur     1      1  DEVENDRA SINGH ALIAS BHOLE SINGH    1
# 2          Aligarh     1      1               SATISH KUMAR GAUTAM    1
# 3        Allahabad     1      1                UJJWAL RAMAN SINGH    1
# 4   Ambedkar Nagar     1      1                       LALJI VERMA    1
# ..             ...   ...    ...                               ...  ...
# 75       Shrawasti     1      1               RAM SHIROMANI VERMA    1
# 76         Sitapur     1      1                     RAKESH RATHOR    1
# 77       Sultanpur     1      1                   RAMBHUAL NISHAD    1
# 78           Unnao     1      1   SWAMI SACHCHIDANAND HARI SAKSHI    1
# 79        Varanasi     1      1                     NARENDRA MODI    1
#
# [80 rows x 5 columns]

# %%
cand = Up.groupby(['Candidate'], as_index=False)['Total Votes'].sum().sort_values(by='Total Votes', ascending = False)
cand
# Out:
#                          Candidate  Total Votes
# 28               DR. MAHESH SHARMA       857829
# 13                       ATUL GARG       854170
# 75                     TANUJ PUNIA       719927
# 9                    ANURAG SHARMA       690316
# 58                    RAHUL GANDHI       687649
# ..                             ...          ...
# 21             DAROGA PRASAD SAROJ       439959
# 38                  KAMLESH PASWAN       428693
# 43  KRISHNA DEVI SHIVSHANKER PATEL       406567
# 65             RAMASHANKAR RAJBHAR       405472
# 17                 CHANDAN CHAUHAN       404493
#
# [80 rows x 2 columns]

# %%
plt.figure(figsize=(25,8))
plt.scatter(x="Candidate", y="Total Votes", data=cand, marker="D", s=80)
plt.yticks(fontsize=16)
plt.xticks(rotation='vertical', fontsize=13)
plt.show()

# %%
# To find the total votes of bjp in major state

# %%
bjp = a[a['Party'] == "Bharatiya Janata Party"]
bjp
# Out:
#         ID                      State               Constituency  \
# 0        1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 29      30             Andhra Pradesh                 Anakapalle
# 68      69             Andhra Pradesh                 Araku (ST)
# 275    276             Andhra Pradesh                 Narsapuram
# 354    355             Andhra Pradesh                Rajahmundry
# ...    ...                        ...                        ...
# 8838  8839                West Bengal                    Raiganj
# 8859  8860                West Bengal                   Ranaghat
# 8868  8869                West Bengal                  Srerampur
# 8879  8880                West Bengal                     Tamluk
# 8890  8891                West Bengal                   Uluberia
#
#                                         Candidate                   Party  \
# 0                                 BISHNU PADA RAY  Bharatiya Janata Party
# ...

# %%
bjp_state = bjp.groupby(['State'], as_index=False)['Total Votes'].sum().sort_values(by='Total Votes', ascending=False).head(10)
bjp_state
# Out:
#              State  Total Votes
# 30   Uttar Pradesh     36364011
# 32     West Bengal     23431081
# 17  Madhya Pradesh     22490851
# 9          Gujarat     17989950
# 14       Karnataka     17879261
# 25       Rajasthan     16323452
# 18     Maharashtra     14966577
# 22          Odisha     11410789
# 4            Bihar      8914266
# 6     Chhattisgarh      7930096

# %%
plt.figure(figsize=(20, 10))
wedges, texts, autotexts = plt.pie(
    bjp_state["Total Votes"],
    labels=bjp_state['State'],
    autopct="%1.2f%%",
    shadow=True,
    startangle=140,
    pctdistance=0.85,
    explode=[0.1] * len(bjp_state),
    wedgeprops={'edgecolor': 'black', 'linewidth': 1}
)
plt.legend(wedges, bjp_state['State'], title="States", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))
plt.axis('equal')
plt.title("Top 10 states with higher voting % for BJP")
plt.show()

# %%
cong = a[(a['Party'] == 'Indian National Congress')]
cong_state = cong.groupby(['State'], as_index=False)['Total Votes'].sum().sort_values(by='Total Votes', ascending=False).head(15)
cong_state
# Out:
#              State  Total Votes
# 14       Karnataka     17606669
# 28       Rajasthan     12578823
# 18  Madhya Pradesh     12308049
# 19     Maharashtra      9676935
# 9          Gujarat      9108088
# 31       Telangana      8824961
# 33   Uttar Pradesh      8315527
# 3            Assam      7510363
# 15          Kerala      7003971
# 6     Chhattisgarh      6183101
# 10         Haryana      5702938
# 30      Tamil Nadu      4659734
# 4            Bihar      3996625
# 27          Punjab      3559656
# 13       Jharkhand      3319345

# %%
plt.figure(figsize=(10, 5))
plt.bar(bjp_state['State'], bjp_state['Total Votes'], color='pink')
plt.bar(cong_state['State'], cong_state['Total Votes'], color='blue')
plt.legend(['BJP', 'INC'])
plt.xlabel("States")
plt.ylabel("Total Votes")
plt.title("Top 15 States with highest vote share of BJP AND INC")
plt.xticks(rotation='vertical')
plt.show()

# %%
vote_pr = a.groupby(['Party','State'], as_index=False)['% of Votes'].sum().sort_values(by='% of Votes', ascending=False).head(50)
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
vote_pr
# Out:
#                                                   Party           State  \
# 322                              Bharatiya Janata Party   Uttar Pradesh
# 1138                                    Samajwadi Party   Uttar Pradesh
# 121                        All India Trinamool Congress     West Bengal
# 309                              Bharatiya Janata Party  Madhya Pradesh
# 324                              Bharatiya Janata Party     West Bengal
# 301                              Bharatiya Janata Party         Gujarat
# 306                              Bharatiya Janata Party       Karnataka
# 602                            Indian National Congress       Karnataka
# 310                              Bharatiya Janata Party     Maharashtra
# 317                              Bharatiya Janata Party       Rajasthan
# 475                           Dravida Munnetra Kazhagam      Tamil Nadu
# 1334              Yuvajana Sramika Rythu Congress Party  Andhra Pradesh
# ...

# %%
pivot_df = vote_pr.pivot_table(index='State', columns='Party', values='% of Votes', fill_value=0)

# Plot the stacked bar chart
ax = pivot_df.plot(kind='bar', stacked=True, figsize=(14, 8))

# Add labels and title
plt.xlabel('State')
plt.ylabel('% of Votes')
plt.title(' Top 50 Parties with there votes in each states')
plt.legend(title='Party', bbox_to_anchor=(1.05, 1), loc='upper left')

# Rotate x-axis labels for better readability
plt.xticks(rotation=90)

# Show plot
plt.tight_layout()
plt.show()

# %%
a.head()
# Out:
#    ID                      State               Constituency  \
# 0   1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1   2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2   3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3   4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4   5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
#
#             Candidate                                Party  EVM Votes  \
# 0     BISHNU PADA RAY               Bharatiya Janata Party     102182
# 1  KULDEEP RAI SHARMA             Indian National Congress      77829
# 2          MANOJ PAUL  Andaman Nicobar Democratic Congress       8236
# 3          D AYYAPPAN  Communist Party of India  (Marxist)       6009
# 4     V.K. ABDUL AZIZ                          Independent       2195
#
#    Postal Votes  Total Votes  % of Votes Result
# 0           254       102436       50.58    Won
# 1           211        78040       38.54   Lost
# ...

# %%
bjp_won = a[(a['Party'] == 'Bharatiya Janata Party') & (a['Result'] == 'Won')]
bjp_won
# Out:
#         ID                                 State               Constituency  \
# 0        1             Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 29      30                        Andhra Pradesh                 Anakapalle
# 275    276                        Andhra Pradesh                 Narsapuram
# 354    355                        Andhra Pradesh                Rajahmundry
# 492    493                     Arunachal Pradesh             Arunachal East
# 499    500                     Arunachal Pradesh             Arunachal West
# 523    524                                 Assam           Darrang0Udalguri
# 549    550                                 Assam                  Dibrugarh
# 553    554                                 Assam                      Diphu
# 559    560                                 Assam                   Guwahati
# 573    574                                 Assam                  Karimganj
# ...

# %%
cong_won = a[(a['Party'] == 'Indian National Congress') & (a['Result'] == 'Won')]
cong_won
# Out:
#         ID          State          Constituency  \
# 535    536          Assam                Dhubri
# 568    569          Assam                Jorhat
# 633    634          Assam                Nagaon
# 850    851          Bihar               Katihar
# 873    874          Bihar            Kishanganj
# 1092  1093          Bihar               Sasaram
# 1202  1203     Chandigarh            Chandigarh
# 1327  1328   Chhattisgarh                 KORBA
# 1476  1477            Goa             South Goa
# 1528  1529        Gujarat           Banaskantha
# 1776  1777        Haryana                AMBALA
# 1858  1859        Haryana                 HISAR
# 1939  1940        Haryana                ROHTAK
# 1966  1967        Haryana                 SIRSA
# 1986  1987        Haryana               SONIPAT
# 2305  2306      Jharkhand                Khunti
# 2329  2330      Jharkhand             Lohardaga
# 2536  2537      Karnataka               Bellary
# ...

# %%
abc = bjp_won.groupby(['Constituency','State'], as_index=False)['Result'].describe().sort_values(by='State', ascending=True)
abc
# Out:
#                   Constituency                                 State count  \
# 15   Andaman & Nicobar Islands             Andaman & Nicobar Islands     1
# 196                Rajahmundry                        Andhra Pradesh     1
# 166                 Narsapuram                        Andhra Pradesh     1
# 13                  Anakapalle                        Andhra Pradesh     1
# 18              Arunachal West                     Arunachal Pradesh     1
# 17              Arunachal East                     Arunachal Pradesh     1
# 94                    Guwahati                                 Assam     1
# 135                  Kaziranga                                 Assam     1
# 133                  Karimganj                                 Assam     1
# 78                       Diphu                                 Assam     1
# 216                   Sonitpur                                 Assam     1
# ...

# %%
xyz = cong_won.groupby(['Constituency','State'], as_index=False)['Result'].describe().sort_values(by='State', ascending=True)
xyz
# Out:
#             Constituency          State count unique  top freq
# 66                Nagaon          Assam     1      1  Won    1
# 40                Jorhat          Assam     1      1  Won    1
# 24                Dhubri          Assam     1      1  Won    1
# 85               Sasaram          Bihar     1      1  Won    1
# 51            Kishanganj          Bihar     1      1  Won    1
# 48               Katihar          Bihar     1      1  Won    1
# 19            Chandigarh     Chandigarh     1      1  Won    1
# 44                 KORBA   Chhattisgarh     1      1  Won    1
# 88             South Goa            Goa     1      1  Won    1
# 9            Banaskantha        Gujarat     1      1  Won    1
# 81                 SIRSA        Haryana     1      1  Won    1
# 77                ROHTAK        Haryana     1      1  Won    1
# 83               SONIPAT        Haryana     1      1  Won    1
# 33                 HISAR        Haryana     1      1  Won    1
# ...

# %%
plt.figure(figsize=(20, 8))
sns.countplot(data=xyz, x='State', order=xyz['State'].value_counts().index)
plt.yticks(ticks=range(0,  16, 2))
plt.title('Number of Constituencies Won by INC in diffrent State')
plt.xlabel('State')
plt.ylabel('Number of Constituencies')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.figure(figsize=(20, 8))
sns.countplot(data=abc, x='State', color='orange', order=abc['State'].value_counts().index)
plt.yticks(ticks=range(0, 36, 2))
plt.title('Number of Constituencies Won by BJP in diffrent State')
plt.xlabel('State')
plt.ylabel('Number of Constituencies')
plt.xticks(rotation='vertical')
plt.show()

# %%
a.head(50)
# Out:
#     ID                      State               Constituency  \
# 0    1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1    2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2    3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3    4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4    5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 5    6  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 6    7  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 7    8  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 8    9  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 9   10  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 10  11  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 11  12  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 12  13  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 13  14             Andhra Pradesh            Amalapuram (SC)
# ...

# %%
won = a[(a['Result'] == 'Won')]
won
# Out:
#         ID                                 State               Constituency  \
# 0        1             Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 13      14                        Andhra Pradesh            Amalapuram (SC)
# 29      30                        Andhra Pradesh                 Anakapalle
# 45      46                        Andhra Pradesh                 Ananthapur
# 67      68                        Andhra Pradesh                 Araku (ST)
# 81      82                        Andhra Pradesh               Bapatla (SC)
# 97      98                        Andhra Pradesh               Chittoor(SC)
# 117    118                        Andhra Pradesh                      Eluru
# 131    132                        Andhra Pradesh                     Guntur
# 162    163                        Andhra Pradesh                   Hindupur
# 176    177                        Andhra Pradesh                     Kadapa
# ...

# %%
cons_grp = won.groupby(['State', 'Constituency', 'Candidate', 'Party'], as_index=False)['Result'].count().sort_values(by='State', ascending=True)
cons_grp
# Out:
#                                     State               Constituency  \
# 0               Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 25                         Andhra Pradesh               Vizianagaram
# 24                         Andhra Pradesh              Visakhapatnam
# 23                         Andhra Pradesh                 Vijayawada
# 22                         Andhra Pradesh             Thirupathi(SC)
# 21                         Andhra Pradesh                 Srikakulam
# 20                         Andhra Pradesh                   Rajampet
# 19                         Andhra Pradesh                Rajahmundry
# 18                         Andhra Pradesh                     Ongole
# 16                         Andhra Pradesh                Narsaraopet
# 15                         Andhra Pradesh                 Narsapuram
# 14                         Andhra Pradesh                    Nandyal
# 13                         Andhra Pradesh              Machilipatnam
# ...

# %%
# To find the total postal votes in each state
# To find the total postal votes for each party.

# %%
postal_state = a.groupby(['State'], as_index=False)['Postal Votes'].sum().sort_values(by='State', ascending=True)
postal_state
# Out:
#                                    State  Postal Votes
# 0              Andaman & Nicobar Islands           522
# 1                         Andhra Pradesh        470837
# 2                      Arunachal Pradesh         33423
# 3                                  Assam        106611
# 4                                  Bihar        138978
# 5                             Chandigarh           727
# 6                           Chhattisgarh         37709
# 7   Dadra & Nagar Haveli and Daman & Diu           462
# 8                                    Goa          9560
# 9                                Gujarat        276226
# 10                               Haryana         51237
# 11                      Himachal Pradesh         71135
# 12                     Jammu and Kashmir         42867
# 13                             Jharkhand        169875
# 14                             Karnataka        149948
# 15                                Kerala        222031
# ...

# %%
plt.figure(figsize=(20,10))
sns.stripplot(x='State', y='Postal Votes', data=postal_state, size=11, color='red')
plt.yticks(ticks=range(0, 500000, 20000))
plt.xticks(rotation=90)
plt.title("States with ther total postal votes")
plt.xlabel('State', size=15)
plt.ylabel('Postal Votes', size=15)
plt.show()

# %%
postal_party = a.groupby(['Party'], as_index=False)['Postal Votes'].sum().sort_values(by='Postal Votes', ascending=False).head(20)
postal_party
# Out:
#                                         Party  Postal Votes
# 158                    Bharatiya Janata Party       1360719
# 289                  Indian National Congress        848529
# 698                              Telugu Desam        206091
# 744     Yuvajana Sramika Rythu Congress Party        141165
# 69               All India Trinamool Congress        112023
# 227       Communist Party of India  (Marxist)        104844
# 282                               Independent         89256
# 617                           Samajwadi Party         83274
# 250                 Dravida Munnetra Kazhagam         64831
# 121                       Bahujan Samaj Party         48663
# 471                         None of the Above         47542
# 55   All India Anna Dravida Munnetra Kazhagam         45816
# 539                      Rashtriya Janata Dal         45369
# 657     Shiv Sena (Uddhav Balasaheb Thackrey)         44982
# 217                           Biju Janata Dal         30668
# ...

# %%
plt.figure(figsize=(20,10))
plt.bar(postal_party['Party'], postal_party['Postal Votes'], color='orange')
#plt.bar(postal_state['State'], postal_state['Postal Votes'], color='green')
plt.title("Parties with there total number of postal votes")
plt.xlabel('Parties', size=15)
plt.ylabel('Postal Votes', size=15)
plt.xticks(rotation=90)
plt.show()

# %%
# To find total number of constituency in each state

# %%
constituency_counts = a.groupby('State')['Constituency'].nunique().reset_index()
constituency_counts.rename(columns={'Constituency': 'Total Constituencies'}, inplace=True)
constituency_counts
# Out:
#                                    State  Total Constituencies
# 0              Andaman & Nicobar Islands                     1
# 1                         Andhra Pradesh                    25
# 2                      Arunachal Pradesh                     2
# 3                                  Assam                    14
# 4                                  Bihar                    40
# 5                             Chandigarh                     1
# 6                           Chhattisgarh                    11
# 7   Dadra & Nagar Haveli and Daman & Diu                     2
# 8                                    Goa                     2
# 9                                Gujarat                    26
# 10                               Haryana                    10
# 11                      Himachal Pradesh                     4
# 12                     Jammu and Kashmir                     5
# 13                             Jharkhand                    14
# ...

# %%
plt.figure(figsize=(15,10))
plt.stem(constituency_counts['State'], constituency_counts['Total Constituencies'], linefmt ='black', markerfmt ='D')
plt.title("Total number of constituencies in each state")
plt.xticks(rotation=90)
plt.show()

# %%
# To find the name of the candidate whos has won with more the 65 % of votes with there constituency and party name.

# %%
Result_won = a[(a['Result'] == 'Won') & (a['% of Votes'] > 65)]
Result_won
# Out:
#         ID           State     Constituency  \
# 442    443  Andhra Pradesh    Visakhapatnam
# 1387  1388    Chhattisgarh           RAIPUR
# 1485  1486         Gujarat   Ahmedabad East
# 1511  1512         Gujarat           Amreli
# 1559  1560         Gujarat        Bhavnagar
# 1590  1591         Gujarat      Gandhinagar
# 1664  1665         Gujarat          Navsari
# 1679  1680         Gujarat       Panchmahal
# 1699  1700         Gujarat        Porbandar
# 1712  1713         Gujarat           Rajkot
# 1753  1754         Gujarat         Vadodara
# 3169  3170  Madhya Pradesh           BHOPAL
# 3208  3209  Madhya Pradesh            DAMOH
# 3240  3241  Madhya Pradesh             GUNA
# 3289  3290  Madhya Pradesh           INDORE
# 3304  3305  Madhya Pradesh         JABALPUR
# 3324  3325  Madhya Pradesh        KHAJURAHO
# 3372  3373  Madhya Pradesh         MANDSOUR
# 3441  3442  Madhya Pradesh            SAGAR
# 3504  3505  Madhya Pradesh        TIKAMGARH
# ...

# %%
plt.figure(figsize=(20,10))
#sns.barplot(x='Candidate', y='% of Votes', data=Result_won)
plt.bar(Result_won['Candidate'], Result_won['% of Votes'], color='cyan')
plt.xticks(rotation='vertical')
plt.title('Candidates who won with more then 65% of votes', size=15)
plt.xlabel('Candidates Name', size=15)
plt.ylabel('% of Votes', size=15)
plt.show()

# %%
a.head()
# Out:
#    ID                      State               Constituency  \
# 0   1  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 1   2  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 2   3  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 3   4  Andaman & Nicobar Islands  Andaman & Nicobar Islands
# 4   5  Andaman & Nicobar Islands  Andaman & Nicobar Islands
#
#             Candidate                                Party  EVM Votes  \
# 0     BISHNU PADA RAY               Bharatiya Janata Party     102182
# 1  KULDEEP RAI SHARMA             Indian National Congress      77829
# 2          MANOJ PAUL  Andaman Nicobar Democratic Congress       8236
# 3          D AYYAPPAN  Communist Party of India  (Marxist)       6009
# 4     V.K. ABDUL AZIZ                          Independent       2195
#
#    Postal Votes  Total Votes  % of Votes Result
# 0           254       102436       50.58    Won
# 1           211        78040       38.54   Lost
# ...

# %%
a['Party'].nunique() # Total number of parties participated in the loksabha election of 2024
# Out:
# 746

# %%
a['Total Votes'].sum()
# Out:
# 645363445

# %%
# Total population of india is 1417238585 Cr
# And total number of votes occured is 645363445
# So to obtain total vote %

# %%
(645363445/1417238585)*100
# Out:
# 45.53668322542884

# %%
a['% of Votes'].mean()
# Out:
# 6.0884879802291625

# %%
a['Constituency'].nunique()
# Out:
# 541
